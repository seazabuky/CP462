# %% [markdown]
# นิธิศ เกิดช่วย 64102010078

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import imageio

# %%
photo = imageio.v3.imread('ricardo.jpg')
plt.figure(figsize=(10,10))
plt.imshow(photo)

# %%
photo_data = photo.copy()
photo_data[325:375,250:350]= 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)
